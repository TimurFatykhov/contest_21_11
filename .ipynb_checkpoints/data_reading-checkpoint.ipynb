# %%
import numpy as np 
import glob 
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# #### Load the train data

# %%
# %%time 

postures = ['A', 'B', 'C', 'Five', 'V', 'Point']
X = []
y_train = []
img_size = 64


for name in postures:
    samples = glob.glob('./blended_train/' + name + '/*.JPG')
    
    for s in samples:
        img = mpimg.imread(s)
        X.append(img)
        y_train.append(name)
        
y_train = np.array(y_train)
        
n = len(X)
X_train = np.ndarray((n, img_size, img_size, 3), np.int32)
for i in range(n):
    X_train[i] = X[i]
# Out:
# CPU times: user 2.13 s, sys: 808 ms, total: 2.94 s
# Wall time: 3.92 s

# %% [markdown]
# #### Show train image #4002

# %%
plt.imshow(X_train[4002])
